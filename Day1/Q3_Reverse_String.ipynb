# %%
string = "Python Programming"

print(string[::-1])
# Out:
# gnimmargorP nohtyP

# %% [markdown]
# ## Answer
#
# Python supports string slicing using the syntax `string[start:stop:step]`.
#
# Using `[::-1]`:
#
# - Starts from the end of the string.
# - Moves backward with a step of `-1`.
# - Returns the reversed string.
#
# ### Output
#
# ```text
# gnimmargorP nohtyP
# ```
